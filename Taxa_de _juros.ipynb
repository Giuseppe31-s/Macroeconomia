# %%
import numpy as np
import pandas as pd 
# %matplotlib inline

# %%
taxas = pd.read_csv(r'C:\Users\Giuseppe\Desktop\programa\pynthino\taxa_de_juros.csv',sep= ';')

# %%
taxas.head()
# Out:
#     Data  Taxa
# 0  03/11  2,62
# 1  04/11  2,66
# 2  05/11  2,65
# 3  06/11  2,63
# 4  07/11  2,65

# %%
taxas.dtypes
# Out:
# Data    object
# Taxa    object
# dtype: object

# %%
taxas.Data = pd.to_datetime(taxas.Data, format='%m/%y')

# %%
taxas.dtypes
# Out:
# Data    datetime64[ns]
# Taxa            object
# dtype: object

# %%
taxas.Taxa = taxas.Taxa.str.replace(',','.').astype(float)

# %%
taxas.head()
# Out:
#         Data  Taxa
# 0 2011-03-01  2.62
# 1 2011-04-01  2.66
# 2 2011-05-01  2.65
# 3 2011-06-01  2.63
# 4 2011-07-01  2.65

# %%
taxas.plot(x= "Data", y= 'Taxa')
